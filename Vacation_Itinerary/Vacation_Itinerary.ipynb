# %% [markdown]
# ## Deliverable 3. Create a Travel Itinerary Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
import sys
sys.path.append("../")
from config import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
vacation_df = pd.read_csv("../Vacation_Search/WeatherPy_vacation.csv")
vacation_df.head()
# Out:
#    City_ID            City Country  Max Temp Current Description      Lat  \
# 0        9     George Town      MY     87.89          few clouds   5.4112
# 1       12  Cabo San Lucas      MX     83.61     overcast clouds  22.8909
# 2       15        Waingapu      ID     86.79          few clouds  -9.6567
# 3       17   San Cristobal      VE     75.38     overcast clouds   7.7669
# 4       26          Marawi      PH     85.50     overcast clouds   7.9986
#
#         Lng              Hotel Name
# 0  100.3354          Cititel Penang
# 1 -109.9124  Hotel Tesoro Los Cabos
# 2  120.2641      Pondok Wisata Elim
# 3  -72.2250    Posada Villaven C.A.
# 4  124.2928    Derogongan Residence

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Weather Description</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in vacation_df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = vacation_df[["Lat", "Lng"]]

# %%
# 4a. Add a marker layer for each city to the map.
locations = vacation_df[["Lat", "Lng"]]
max_temp = vacation_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# 4b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
vacation_df[vacation_df["Country"] == "US"].head(20)
# Out:
#      City_ID           City Country  Max Temp   Current Description      Lat  \
# 5         27        Kahului      US     82.42             clear sky  20.8947
# 11        46           Hilo      US     76.80  heavy intensity rain  19.7297
# 28        96          Kapaa      US     84.52             clear sky  22.0752
# 44       159      Fairbanks      US     82.40      scattered clouds  64.8378
# 45       163  Saint Anthony      US     76.71             clear sky  45.0205
# 47       175   Rapid Valley      US     75.38            few clouds  44.0625
# 53       187   San Patricio      US     84.83       overcast clouds  28.0170
# 58       201         Hayden      US     89.26             clear sky  47.7660
# 70       244       Portland      US     89.64                 smoke  45.5234
# 81       271  Makakilo City      US     80.92         broken clouds  21.3469
# 85       281     Sweetwater      US     84.02       overcast clouds  25.7634
# ...

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.

vacation_start = vacation_df.loc[53]
vacation_end = vacation_df.loc[53]
vacation_stop1 = vacation_df.loc[70]
vacation_stop2 = vacation_df.loc[85] 
vacation_stop3 = vacation_df.loc[115] 

vacation_start
# Out:
# City_ID                               187
# City                         San Patricio
# Country                                US
# Max Temp                            84.83
# Current Description       overcast clouds
# Lat                                28.017
# Lng                              -97.5169
# Hotel Name             Motel 6 Sinton, TX
# Name: 53, dtype: object

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
start = tuple(vacation_start[["Lat","Lng"]].to_numpy())
end = tuple(vacation_end[["Lat","Lng"]].to_numpy())
stop1 = tuple(vacation_stop1[["Lat","Lng"]].to_numpy())
stop2 = tuple(vacation_stop2[["Lat","Lng"]].to_numpy())
stop3 = tuple(vacation_stop3[["Lat","Lng"]].to_numpy())

stop1
# Out:
# (45.5234, -122.6762)

# %%
# Import required module for gmaps directions
import gmaps.datasets

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".
fig = gmaps.figure()
travel_route = gmaps.directions_layer(start,end,waypoints=[stop1,stop2,stop3],travel_mode="DRIVING")
fig.add_layer(travel_route)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.
#  Concat requires multiple dataframes but the instruction so far required me to create series...
#  Creating variables for individual DFs to use concat

vacation_start_df = vacation_df[vacation_df["City"] == "San Patricio"]
vacation_end_df = vacation_start_df.copy()
vacation_stop1_df = vacation_df[vacation_df["City"] == "Portland"]
vacation_stop2_df = vacation_df[vacation_df["City"] == "Sweetwater"]
vacation_stop3_df = vacation_df[vacation_df["City"] == "Susanville"]

itinerary_df = pd.concat([vacation_start_df,vacation_stop1_df,vacation_stop2_df,vacation_stop3_df],ignore_index=True)
itinerary_df
# Out:
#    City_ID          City Country  Max Temp Current Description      Lat  \
# 0      187  San Patricio      US     84.83     overcast clouds  28.0170
# 1      244      Portland      US     89.64               smoke  45.5234
# 2      281    Sweetwater      US     84.02     overcast clouds  25.7634
# 3      389    Susanville      US     82.24           clear sky  40.4163
#
#         Lng                                  Hotel Name
# 0  -97.5169                          Motel 6 Sinton, TX
# 1 -122.6762  Embassy Suites by Hilton Portland Downtown
# 2  -80.3731                 Li'l Abner Mobile Home Park
# 3 -120.6530                        Comfort Inn & Suites

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
fig = gmaps.figure()

info_box_template = """
<dl>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Weather Description</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in itinerary_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = itinerary_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map.
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)
# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
